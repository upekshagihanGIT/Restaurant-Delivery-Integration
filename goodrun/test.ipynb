# %%
import pandas as pd

# %%
df = pd.read_csv("nn_cluster0_num_of_deliveries.csv", header=None, names=["date", "number"])
df["number"].describe()
# Out:
# count    29.000000
# mean      3.275862
# std       1.887866
# min       1.000000
# 25%       1.000000
# 50%       3.000000
# 75%       5.000000
# max       6.000000
# Name: number, dtype: float64
