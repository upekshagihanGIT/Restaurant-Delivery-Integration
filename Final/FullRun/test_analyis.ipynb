# %%
import pandas as pd
import numpy as np

# %%
dt = [1, 2, 3, 4, 5]
print(dt[:-2])
# Out:
# [1, 2, 3]

# %%
loc_df = df[["Restaurant_latitude", "Restaurant_longitude"]]

# %%
loc_df = loc_df.groupby(by=["Restaurant_latitude", "Restaurant_longitude"]).size().reset_index(name="Count").sort_values(by="Count", ascending=False)

# %%
loc_df
# Out:
#      Restaurant_latitude  Restaurant_longitude  Count
# 315             0.000000              0.000000   3640
# 653            26.911378             75.789034    182
# 658            26.914142             75.805704    180
# 646            26.892312             75.806896    176
# 648            26.902908             75.792934    176
# ..                   ...                   ...    ...
# 44            -26.902940             75.793007      1
# 51            -26.483042             80.317833      1
# 46            -26.846156             75.802300      1
# 47            -26.766536            -75.837333      1
# 48            -26.766536             75.837333      1
#
# [704 rows x 3 columns]
