# %%
from IPython.core.interactiveshell import InteractiveShell

# %%
shell = InteractiveShell.instance()

# %%
print("Hello")
# Out:
# Hello

# %%
for i in range(5):
    print(f"Number {i+1}")
    shell.run_cell_by_id(cell_id="1")
# Out:
# Number 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 for i in range(5):
#       2     print(f"Number {i+1}")
# ----> 3     shell.run_cell_by_id(cell_id="1")
#
# AttributeError: 'ZMQInteractiveShell' object has no attribute 'run_cell_by_id'
