# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn

# %%
df = pd.read_csv("restaurant_deliveries_2024.csv")
df.head()
# Out:
#    Order Date  Customer Latitude  Customer Longitude
# 0  2024-04-12           6.995278           79.795438
# 1  2024-12-14           6.883918           79.859301
# 2  2024-09-27           6.848062           79.787815
# 3  2024-04-16           6.908621           79.941768
# 4  2024-03-12           7.000688           79.855024

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order Date          50000 non-null  datetime64[ns]
#  1   Customer Latitude   50000 non-null  float64
#  2   Customer Longitude  50000 non-null  float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 1.1 MB

# %%
scaler1 = StandardScaler()
df[["Latitude_Scaled", "Longitude_Scaled"]] = scaler1.fit_transform(df[["Customer Latitude", "Customer Longitude"]])
df.head()
# Out:
#   Order Date  Customer Latitude  Customer Longitude  Latitude_Scaled  \
# 0 2024-04-12           6.995278           79.795438         1.314191
# 1 2024-12-14           6.883918           79.859301        -0.829003
# 2 2024-09-27           6.848062           79.787815        -1.519070
# 3 2024-04-16           6.908621           79.941768        -0.353568
# 4 2024-03-12           7.000688           79.855024         1.418312
#
#    Longitude_Scaled
# 0         -1.251001
# 1         -0.033932
# 2         -1.396282
# 3          1.537662
# 4         -0.115444

# %%
def elbow_method(data, max_k):
    means = []
    inertias = []
    for k1 in range(1, max_k+1):
        kmeans_elbow = KMeans(n_clusters=k1)
        kmeans_elbow.fit(data)
        means.append(k1)
        inertias.append(kmeans_elbow.inertia_)
    
    plt.plot(means, inertias, 'o-')
    plt.xlabel("K-Means")
    plt.ylabel("Intertias")
    plt.grid(True)
    plt.show()

# %%
elbow_method(df[["Latitude_Scaled", "Longitude_Scaled"]], 10)
# Out:
# c:\Users\upeks\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\upeks\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "c:\Users\upeks\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\upeks\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 1026, in __init__
# ...

# %%
kmeans_optimal = KMeans(n_clusters=4)
kmeans_optimal.fit(df[["Latitude_Scaled", "Longitude_Scaled"]])
df["K-Means = 4"] = kmeans_optimal.labels_
df.head()
# Out:
#   Order Date  Customer Latitude  Customer Longitude  Latitude_Scaled  \
# 0 2024-04-12           6.995278           79.795438         1.314191
# 1 2024-12-14           6.883918           79.859301        -0.829003
# 2 2024-09-27           6.848062           79.787815        -1.519070
# 3 2024-04-16           6.908621           79.941768        -0.353568
# 4 2024-03-12           7.000688           79.855024         1.418312
#
#    Longitude_Scaled  K-Means = 4
# 0         -1.251001            1
# 1         -0.033932            0
# 2         -1.396282            0
# 3          1.537662            3
# 4         -0.115444            1

# %%
df_cluster0 = df[df["K-Means = 4"] == 0]
df_cluster0.head()
# Out:
#    Order Date  Customer Latitude  Customer Longitude  Latitude_Scaled  \
# 1  2024-12-14           6.883918           79.859301        -0.829003
# 2  2024-09-27           6.848062           79.787815        -1.519070
# 5  2024-07-07           6.862624           79.802775        -1.238813
# 6  2024-01-21           6.905036           79.808577        -0.422565
# 10 2024-11-26           6.925479           79.787969        -0.029137
#
#     Longitude_Scaled  K-Means = 4
# 1          -0.033932            0
# 2          -1.396282            0
# 5          -1.111183            0
# 6          -1.000610            0
# 10         -1.393353            0

# %%
df_cluster0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12493 entries, 1 to 49995
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order Date          12493 non-null  datetime64[ns]
#  1   Customer Latitude   12493 non-null  float64
#  2   Customer Longitude  12493 non-null  float64
#  3   Latitude_Scaled     12493 non-null  float64
#  4   Longitude_Scaled    12493 non-null  float64
#  5   K-Means = 4         12493 non-null  int32
# dtypes: datetime64[ns](1), float64(4), int32(1)
# memory usage: 634.4 KB

# %%
df_cluster0.sort_values(by="Order Date", inplace=True)
df_grouped = df_cluster0.groupby(by="Order Date").size().reset_index(name="Number of Orders")
df_grouped.head()
# Out:
# C:\Users\upeks\AppData\Local\Temp\ipykernel_12128\88498698.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cluster0.sort_values(by="Order Date", inplace=True)
#   Order Date  Number of Orders
# 0 2024-01-01                39
# 1 2024-01-02                33
# 2 2024-01-03                28
# 3 2024-01-04                35
# 4 2024-01-05                30
