# %%
import numpy as np

# %%
arr = np.array([4, 6, 12])

# %%
arr.shape
# Out:
# (3,)

# %%
np.max(arr)
# Out:
# np.int64(12)

# %%
arr = arr.reshape(-1, 1)

# %%
arr.shape
# Out:
# (3, 1)

# %%
np.max(arr)
# Out:
# np.int64(12)
