# %%
import urllib.request
import json

# %%
formatted_addresses = []
real_addresses = [
    "205 E Houston St, New York, NY 10002",  
    "201 E Houston St, New York, NY 10002",  
    "210 E Houston St, New York, NY 10002",  
    "15 Orchard St, New York, NY 10002",  
    "118 Ludlow St, New York, NY 10002",  
    "151 Essex St, New York, NY 10002",  
    "172 Rivington St, New York, NY 10002",  
    "57 Stanton St, New York, NY 10002",  
    "98 Norfolk St, New York, NY 10002",  
    "105 Allen St, New York, NY 10002",  
    "121 Eldridge St, New York, NY 10002",  
    "136 Orchard St, New York, NY 10002",  
    "78 Clinton St, New York, NY 10002",  
    "25 Attorney St, New York, NY 10002",  
    "165 Suffolk St, New York, NY 10002",  
    "11 Delancey St, New York, NY 10002" 
]
for ra in real_addresses:
    ra = ra.replace(',','')
    ra = ra.replace(' ','+')
    formatted_addresses.append(ra)

# %%
def create_data():
    data = {}
    data["API_key"] = "AIzaSyA8-2qB0oHHBSWFFCyfCXcmHxFBpf8lUmo"
    data["addresses"] = formatted_addresses
    return data

# %%
def build_distance_matrix(response):
    distance_matrix = []
    for row in response["rows"]:
        row_list = [row["elements"][j]["distance"]["value"] for j in range(len(row["elements"]))]
        distance_matrix.append(row_list)
    return distance_matrix

# %%
def send_request(origin_addressses, dest_addresses, API_key):
    def build_address_str(addresses):
        address_str = ""
        for i in range(len(addresses)-1):
            address_str += addresses[i] + '|'
        address_str += addresses[-1]
        return address_str
    request = "https://maps.googleapis.com/maps/api/distancematrix/json?units=imperial"
    origin_address_str = build_address_str(origin_addressses)
    dest_address_str = build_address_str(dest_addresses)
    request = request+"&origins="+origin_address_str+"&destinations="+dest_address_str+"&key="+API_key
    jsonResult = urllib.request.urlopen(request).read()
    response = json.loads(jsonResult)
    print(jsonResult)
    return response

# %%
def create_distance_matrix(data):
    addresses = data["addresses"]
    API_key = data["API_key"]
    max_elements = 100
    num_addresses = len(addresses)
    max_rows = max_elements // num_addresses
    q, r = divmod(num_addresses, max_rows)
    dest_addresses = addresses
    distance_matrix = []
    for i in range(q):
        origin_addresses = addresses[i*max_rows:(i+1)*max_rows]
        response = send_request(origin_addresses, dest_addresses, API_key)
        distance_matrix += build_distance_matrix(response)
    if r > 0:
        origin_addresses = addresses[q*max_rows:(q*max_rows)+r]
        response = send_request(origin_addresses, dest_addresses, API_key)
        distance_matrix += build_distance_matrix(response)
    return distance_matrix

# %%
def main():
    data = create_data()
    distance_matrix = create_distance_matrix(data)
    print(distance_matrix)
if __name__ == '__main__':
  main()
# Out:
# b'{\n   "destination_addresses" : \n   [\n      "205 E Houston St, New York, NY 10002, USA",\n      "201 E Houston St, New York, NY 10002, USA",\n      "210 E Houston St, New York, NY 10002, USA",\n      "15 Orchard St, New York, NY 10002, USA",\n      "118 Ludlow St, New York, NY 10002, USA",\n      "151 Essex St, New York, NY 10002, USA",\n      "172 Rivington St, New York, NY 10002, USA",\n      "57 Stanton St, New York, NY 10002, USA",\n      "98 Norfolk St, New York, NY 10002, USA",\n      "105 Allen St, New York, NY 10002, USA",\n      "121 Eldridge St, New York, NY 10002, USA",\n      "136 Orchard St, New York, NY 10002, USA",\n      "78 Clinton St, New York, NY 10002, USA",\n      "25 Attorney St, New York, NY 10002, USA",\n      "165 Suffolk St, New York, NY 10002, USA",\n      "11 Delancey St, New York, NY 10002, USA"\n   ],\n   "origin_addresses" : \n   [\n      "205 E Houston St, New York, NY 10002, USA",\n      "201 E Houston St, New York, NY 10002, USA",\n      "210 E H
# ...
