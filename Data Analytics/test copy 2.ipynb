# %%
import torch
from torch.utils.data import Dataset

class CustomDataset(Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        sample = self.data[idx]
        label = self.labels[idx]
        return sample, label

# Example Data
data = torch.randn(100, 3)  # 100 samples, 3 features each
labels = torch.randint(0, 2, (100,))  # Binary labels for each sample

dataset = CustomDataset(data, labels)



# Access data
print(f"Dataset size: {len(dataset)}")
print(f"Sample 0: {dataset[0]}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 23
#      19 labels = torch.randint(0, 2, (100,))  # Binary labels for each sample
#      21 dataset = CustomDataset(data, labels)
# ---> 23 dataset.shape
#      25 # Access data
#      26 print(f"Dataset size: {len(dataset)}")
#
# AttributeError: 'CustomDataset' object has no attribute 'shape'
